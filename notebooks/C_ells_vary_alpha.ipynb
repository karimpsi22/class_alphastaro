# %%
import numpy as np
import classy
import matplotlib.pyplot as plt
import scienceplots
plt.style.use(['science', 'notebook','ieee'])
import pandas as pd
import requests
import io

# %%
# 1. Define Fixed Parameters (Planck 2018)
omega_b = 0.02237
omega_cdm = 0.1200
h = 0.6736
tau_reio = 0.0544
N_star = 60.0
log_V0 = -12.0

# 2. Values of alpha to test
alpha_values = np.linspace(0.1, 10, 200)  # 21 points from 0.1 to 10.0
l_max = 3500

results = {}

# %%
for alpha in alpha_values:
    print(f"Computing for alpha = {alpha}...")
    
    cosmo = classy.Class()
    params = {
        'output': 'tCl,pCl,lCl',
        'modes': 's,t',
        'lensing': 'yes',
        'omega_b': omega_b,
        'omega_cdm': omega_cdm,
        'h': h,
        'tau_reio': tau_reio,
        'N_star': N_star,
        'l_max_scalars': l_max,
        'Pk_ini_type': 'inflation_V_end',
        'full_potential': 'alphastaro',
        'inflation_behavior': 'numerical',
        'Vparam0': 10.**log_V0,
        'Vparam1': alpha, # This is your alpha
        'k_pivot': 0.05
    }
    
    try:
        cosmo.set(params)
        cosmo.compute()
        
        # Get lensed Cls
        cls = cosmo.lensed_cl(l_max)
        ell = cls['ell']
        # Factor l(l+1)/2pi to get D_l
        factor = ell * (ell + 1) / (2 * np.pi)
        
        results[alpha] = {
            'ell': ell,
            'tt': cls['tt'] * factor * 1e12 # Convert to muK^2
        }
        
    except Exception as e:
        print(f"Failed at alpha {alpha}: {e}")
    
    cosmo.struct_cleanup()
    cosmo.empty()
# Out:
# Computing for alpha = 0.1...
# Computing for alpha = 0.14974874371859298...
# Computing for alpha = 0.19949748743718593...
# Computing for alpha = 0.2492462311557789...
# Computing for alpha = 0.2989949748743719...
# Computing for alpha = 0.3487437185929648...
# Computing for alpha = 0.39849246231155777...
# Computing for alpha = 0.44824120603015083...
# Computing for alpha = 0.4979899497487438...
# Computing for alpha = 0.5477386934673367...
# Computing for alpha = 0.5974874371859297...
# Computing for alpha = 0.6472361809045226...
# Computing for alpha = 0.6969849246231156...
# Computing for alpha = 0.7467336683417085...
# Computing for alpha = 0.7964824120603016...
# Computing for alpha = 0.8462311557788945...
# Computing for alpha = 0.8959798994974875...
# Computing for alpha = 0.9457286432160804...
# Computing for alpha = 0.9954773869346734...
# Computing for alpha = 1.0452261306532664...
# Computing for alpha = 1.0949748743718595...
# Computing for alpha = 1.1447236180904523...
# Computing for alpha = 1.1944723618090454...
# Computing for alpha = 1.2442211055276384...
# Computing for alpha = 1.2939698492462313...
# Computing for alpha = 1.3437185929648243...
# Computing for alpha = 1.3934673366834172...
# Computing for alpha = 1.4432160804020102...
# Computing for alpha = 1.4929648241206033...
# Computing for alpha = 1.542713567839196...
# Computing for alpha = 1.5924623115577892...
# Computing for alpha = 1.642211055276382...
# Computing for alpha = 1.691959798994975...
# Computing for alpha = 1.7417085427135681...
# Computing for alpha = 1.791457286432161...
# Computing for alpha = 1.841206030150754...
# Computing for alpha = 1.8909547738693468...
# Computing for alpha = 1.94070351758794...
# Computing for alpha = 1.990452261306533...
# Computing for alpha = 2.040201005025126...
# Computing for alpha = 2.089949748743719...
# Computing for alpha = 2.139698492462312...
# Computing for alpha = 2.1894472361809045...
# Computing for alpha = 2.2391959798994976...
# Computing for alpha = 2.2889447236180906...
# Computing for alpha = 2.3386934673366837...
# Computing for alpha = 2.3884422110552768...
# Computing for alpha = 2.4381909547738694...
# Computing for alpha = 2.4879396984924624...
# Computing for alpha = 2.5376884422110555...
# Computing for alpha = 2.5874371859296486...
# Computing for alpha = 2.6371859296482416...
# Computing for alpha = 2.6869346733668342...
# Computing for alpha = 2.7366834170854273...
# Computing for alpha = 2.7864321608040203...
# Computing for alpha = 2.8361809045226134...
# Computing for alpha = 2.8859296482412065...
# Computing for alpha = 2.935678391959799...
# Computing for alpha = 2.985427135678392...
# Computing for alpha = 3.035175879396985...
# Computing for alpha = 3.0849246231155782...
# Computing for alpha = 3.1346733668341713...
# Computing for alpha = 3.184422110552764...
# Computing for alpha = 3.234170854271357...
# Computing for alpha = 3.28391959798995...
# Computing for alpha = 3.333668341708543...
# Computing for alpha = 3.383417085427136...
# Computing for alpha = 3.4331658291457288...
# Computing for alpha = 3.482914572864322...
# Computing for alpha = 3.532663316582915...
# Computing for alpha = 3.582412060301508...
# Computing for alpha = 3.632160804020101...
# Computing for alpha = 3.6819095477386936...
# Computing for alpha = 3.7316582914572867...
# Computing for alpha = 3.7814070351758797...
# Computing for alpha = 3.831155778894473...
# Computing for alpha = 3.880904522613066...
# Computing for alpha = 3.9306532663316585...
# Computing for alpha = 3.9804020100502515...
# Computing for alpha = 4.030150753768845...
# Computing for alpha = 4.079899497487437...
# Computing for alpha = 4.12964824120603...
# Computing for alpha = 4.179396984924623...
# Computing for alpha = 4.229145728643216...
# Computing for alpha = 4.2788944723618085...
# Computing for alpha = 4.328643216080402...
# Computing for alpha = 4.378391959798995...
# Computing for alpha = 4.428140703517588...
# Computing for alpha = 4.477889447236181...
# Computing for alpha = 4.527638190954773...
# Computing for alpha = 4.577386934673367...
# Computing for alpha = 4.6271356783919595...
# Computing for alpha = 4.676884422110553...
# Computing for alpha = 4.726633165829146...
# Computing for alpha = 4.776381909547738...
# Computing for alpha = 4.826130653266332...
# Computing for alpha = 4.875879396984924...
# Computing for alpha = 4.925628140703518...
# Computing for alpha = 4.9753768844221105...
# Computing for alpha = 5.025125628140703...
# Computing for alpha = 5.074874371859297...
# Computing for alpha = 5.124623115577889...
# Computing for alpha = 5.174371859296483...
# Computing for alpha = 5.224120603015075...
# Computing for alpha = 5.273869346733668...
# Computing for alpha = 5.323618090452261...
# Computing for alpha = 5.373366834170854...
# Computing for alpha = 5.4231155778894475...
# Computing for alpha = 5.47286432160804...
# Computing for alpha = 5.522613065326633...
# Computing for alpha = 5.572361809045226...
# Computing for alpha = 5.622110552763819...
# Computing for alpha = 5.671859296482412...
# Computing for alpha = 5.721608040201005...
# Computing for alpha = 5.771356783919598...
# Computing for alpha = 5.821105527638191...
# Computing for alpha = 5.870854271356784...
# Computing for alpha = 5.920603015075377...
# Computing for alpha = 5.97035175879397...
# Computing for alpha = 6.0201005025125625...
# Computing for alpha = 6.069849246231156...
# Computing for alpha = 6.119597989949749...
# Computing for alpha = 6.169346733668342...
# Computing for alpha = 6.219095477386935...
# Computing for alpha = 6.268844221105527...
# Computing for alpha = 6.318592964824121...
# Computing for alpha = 6.368341708542713...
# Computing for alpha = 6.418090452261307...
# Computing for alpha = 6.4678391959798995...
# Computing for alpha = 6.517587939698492...
# Computing for alpha = 6.567336683417086...
# Computing for alpha = 6.617085427135678...
# Computing for alpha = 6.666834170854272...
# Computing for alpha = 6.716582914572864...
# Computing for alpha = 6.766331658291457...
# Computing for alpha = 6.8160804020100505...
# Computing for alpha = 6.865829145728643...
# Computing for alpha = 6.915577889447237...
# Computing for alpha = 6.965326633165829...
# Computing for alpha = 7.015075376884422...
# Computing for alpha = 7.064824120603015...
# Computing for alpha = 7.114572864321608...
# Computing for alpha = 7.1643216080402015...
# Computing for alpha = 7.214070351758794...
# Computing for alpha = 7.263819095477387...
# Computing for alpha = 7.31356783919598...
# Computing for alpha = 7.363316582914573...
# Computing for alpha = 7.413065326633166...
# Computing for alpha = 7.462814070351759...
# Computing for alpha = 7.5125628140703515...
# Computing for alpha = 7.562311557788945...
# Computing for alpha = 7.612060301507538...
# Computing for alpha = 7.661809045226131...
# Computing for alpha = 7.711557788944724...
# Computing for alpha = 7.761306532663316...
# Computing for alpha = 7.81105527638191...
# Computing for alpha = 7.8608040201005025...
# Computing for alpha = 7.910552763819096...
# Computing for alpha = 7.960301507537689...
# Computing for alpha = 8.010050251256281...
# Computing for alpha = 8.059798994974875...
# Computing for alpha = 8.109547738693468...
# Computing for alpha = 8.15929648241206...
# Computing for alpha = 8.209045226130653...
# Computing for alpha = 8.258793969849247...
# Computing for alpha = 8.308542713567839...
# Computing for alpha = 8.358291457286432...
# Computing for alpha = 8.408040201005026...
# Computing for alpha = 8.457788944723617...
# Computing for alpha = 8.507537688442211...
# Computing for alpha = 8.557286432160804...
# Computing for alpha = 8.607035175879398...
# Computing for alpha = 8.65678391959799...
# Computing for alpha = 8.706532663316583...
# Computing for alpha = 8.756281407035177...
# Computing for alpha = 8.806030150753768...
# Computing for alpha = 8.855778894472362...
# Computing for alpha = 8.905527638190955...
# Computing for alpha = 8.955276381909547...
# Computing for alpha = 9.00502512562814...
# Computing for alpha = 9.054773869346734...
# Computing for alpha = 9.104522613065328...
# Computing for alpha = 9.15427135678392...
# Computing for alpha = 9.204020100502513...
# Computing for alpha = 9.253768844221106...
# Computing for alpha = 9.303517587939698...
# Computing for alpha = 9.353266331658292...
# Computing for alpha = 9.403015075376885...
# Computing for alpha = 9.452763819095477...
# Computing for alpha = 9.50251256281407...
# Computing for alpha = 9.552261306532664...
# Computing for alpha = 9.602010050251257...
# Computing for alpha = 9.651758793969849...
# Computing for alpha = 9.701507537688443...
# Computing for alpha = 9.751256281407036...
# Computing for alpha = 9.801005025125628...
# Computing for alpha = 9.850753768844221...
# Computing for alpha = 9.900502512562815...
# Computing for alpha = 9.950251256281406...
# Computing for alpha = 10.0...

# %%
import urllib.request
# --- 2. DOWNLOAD BOTH PLANCK DATA SETS ---
print("Downloading Planck 2018 data...")
url_binned = "https://irsa.ipac.caltech.edu/data/Planck/release_3/ancillary-data/cosmoparams/COM_PowerSpect_CMB-TT-binned_R3.01.txt"
url_full = "https://irsa.ipac.caltech.edu/data/Planck/release_3/ancillary-data/cosmoparams/COM_PowerSpect_CMB-TT-full_R3.01.txt"

binned_data = np.loadtxt(urllib.request.urlopen(url_binned))
full_data = np.loadtxt(urllib.request.urlopen(url_full))

# Extract Low-ell (unbinned, l < 30)
low_l_mask = full_data[:, 0] < 30
p_l_low = full_data[low_l_mask, 0]
p_dl_low = full_data[low_l_mask, 1]
p_err_low = [full_data[low_l_mask, 2], full_data[low_l_mask, 3]]

# Extract High-ell (binned, usually starts at l=30)
p_l_high = binned_data[:, 0]
p_dl_high = binned_data[:, 1]
p_err_high = [binned_data[:, 2], binned_data[:, 3]]
# Out:
# Downloading Planck 2018 data...

# %%
import numpy as np

# Create an array of log10(alpha) for the color mapping
log_alpha_values = np.log10(alpha_values)

# 3. Plotting the results
plt.figure(figsize=(10, 6))

# --- COLORBAR SETUP ---
cmap = plt.cm.copper # You can change 'viridis' to 'plasma', 'inferno', etc.
# Normalize using the log10 values instead of linear alpha
norm = plt.Normalize(vmin=min(log_alpha_values), vmax=max(log_alpha_values))
# ----------------------

# --- ADDED PLANCK DATA PLOTTING ---
# Low-ell Planck Data (l < 30) - zorder brings it to the front
plt.errorbar(p_l_low, p_dl_low, yerr=p_err_low, fmt='.', color='teal', 
             markersize=5, label='Planck', alpha=1.0, capsize=0, zorder=3)

# High-ell Planck Data (l >= 30) - zorder brings it to the front
plt.errorbar(p_l_high, p_dl_high, yerr=p_err_high, fmt='.', color='teal', 
             markersize=5, alpha=1.0, capsize=0, label='_nolegend_', zorder=3)
# ----------------------------------

for alpha, data in results.items():
    # Evaluate np.log10(alpha) to fetch the correct color from the new norm
    plt.loglog(data['ell'][2:], data['tt'][2:], ls='-', color=cmap(norm(np.log10(alpha))), zorder=1)

plt.xlabel(r'Multipole $\ell$', fontsize=25)
plt.ylabel(r'$D_\ell^{TT} \equiv \ell (\ell+1) C_\ell^{TT}/2\pi \quad [\mu K^2]$', fontsize=25)
# 1. Increase axis tick label sizes
plt.xticks(fontsize=20) 
plt.yticks(fontsize=20)
plt.grid(True, alpha=0.3)
plt.xlim(2, l_max)

# Legend now only shows the Planck data point
plt.legend(frameon=False, fontsize=20) 


# --- DRAW THE COLORBAR ---
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])
cb = plt.colorbar(sm, ax=plt.gca())

# 2. Increase colorbar label and tick sizes
cb.set_label(label=r'$\log_{10}(\alpha)$', size=25) # Change text based on the script
cb.ax.tick_params(labelsize=20) 

plt.tight_layout()
# Save with tight bounding box to include the legend
plt.savefig('TT_vary_alpha.pdf', bbox_inches='tight')

plt.show()
